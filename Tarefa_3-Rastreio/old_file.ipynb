# %%
#https://www.geeksforgeeks.org/python-opencv-cv2-cvtcolor-method/#:~:text=OpenCV%2DPython%20is%20a%20library,conversion%20methods%20available%20in%20OpenCV.
#https://stackoverflow.com/questions/46236180/opencv-imshow-will-cause-jupyter-notebook-crash
# https://docs.opencv.org/4.5.2/d4/dc6/tutorial_py_template_matching.html
#https://stackoverflow.com/questions/753190/programmatically-generate-video-or-animated-gif-in-python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os
import imageio
import numpy as np
from os import listdir
from os.path import isfile, join
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
from tabulate import tabulate


#Informações básicas
path = "/content/drive/MyDrive/PIM/TAREFA FINAL/gatos/"
name_base_file = "gatos"

# %%
def gerar_gif(img_name, imgs, p):
  imageio.mimsave(p+"/"+img_name+".gif", imgs)

# %%
def mostrarImagem(img):
  plt.subplot(122),plt.imshow(img,cmap = 'gray')
  plt.title('Imagem'), plt.xticks([]), plt.yticks([])
  plt.suptitle(cv2.TM_CCOEFF)
  plt.show()

# %%
def criarPasta(name):
  try:
    os.makedirs(name)
  except OSError:
    print("Pasta: "+name+" Já Existe!")

# %%
template = cv2.imread(path+ 'templateGato.png',0)
cv2_imshow(template)
# Out:
# <PIL.Image.Image image mode=L size=244x413 at 0x7F60D5736F50>

# %%
#(Método, Nome da Pasta)
def converter(meth, folder_exit):
  global path, name_base_file
  template = cv2.imread(path+ 'templateGato.png',0)
  images_gif_img = []
  images_gif_res = []
  valores  = []
  w, h = template.shape[::-1]
  path_full = path+""+folder_exit

  criarPasta(path_full)
  criarPasta(path_full+"/res")
  criarPasta(path_full+"/img")

  onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]

  for i in range(1, len(onlyfiles)):
    src = path+name_base_file+'{:0>5}'.format(i)+".png"
    img2 = cv2.imread(src)
    img = img2.copy()
    method = eval(meth)

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #Converte a imagem para tons de cinza

    res = cv2.matchTemplate(gray, template,method)

    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)
    cv2.rectangle(gray,top_left, bottom_right, 255, 2) #Encontra o Objeto na imagem e marca com um retângulo
    #cv2_imshow(gray)

    img_name = folder_exit+'{:0>5}'.format(i)+".png"

    #mostrarImagem(res)
    #mostrarImagem(img)

    cv2.imwrite(path_full+"/res/"+img_name, res)
    cv2.imwrite(path_full+"/img/"+img_name, gray) #Salva a imagem com a marcação

    images_gif_res.append(imageio.imread(path_full+"/res/"+img_name))
    images_gif_img.append(imageio.imread(path_full+"/img/"+img_name))

    valores.append([img_name, min_val, max_val])
    print(name_base_file+'{:0>5}'.format(i)+".png"+" GEROU!")

  arquivo = open(path_full + '/valores.txt','w')
  arquivo.write(tabulate(valores, headers=["Name", "Valor Min", "Valor Max"])) #Armazena os valores máximos e minimos
  arquivo.close()

  gerar_gif("video_res", images_gif_res, path_full )
  gerar_gif("video_img", images_gif_img, path_full)

# %%
converter('cv2.TM_CCOEFF', 'TM_CCOEFF')
# Out:
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCOEFF Já Existe!
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCOEFF/res Já Existe!
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCOEFF/img Já Existe!
# gatos00001.png GEROU!
# gatos00002.png GEROU!
# gatos00003.png GEROU!
# gatos00004.png GEROU!
# gatos00005.png GEROU!
# gatos00006.png GEROU!
# gatos00007.png GEROU!
# gatos00008.png GEROU!
# gatos00009.png GEROU!
# gatos00010.png GEROU!
# gatos00011.png GEROU!
# gatos00012.png GEROU!
# gatos00013.png GEROU!
# gatos00014.png GEROU!
# gatos00015.png GEROU!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-ab5f43fce637> in <module>()
# ----> 1 converter('cv2.TM_CCOEFF', 'TM_CCOEFF')
#
# <ipython-input-23-3ddcaeef74ec> in converter(meth, folder_exit)
#      37
#      38     cv2.imwrite(path_full+"/res/"+img_name, res)
# ---> 39     cv2.imwrite(path_full+"/img/"+img_name, gray) #Salva a imagem com a marcação
#      40
#      41     images_gif_res.append(imageio.imread(path_full+"/res/"+img_name))
#
# KeyboardInterrupt:

# %%
converter('cv2.TM_CCOEFF_NORMED', 'TM_CCOEFF_NORMED')
# Out:
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCOEFF_NORMED Já Existe!
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCOEFF_NORMED/res Já Existe!
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCOEFF_NORMED/img Já Existe!
# gatos00001.png GEROU!
# gatos00002.png GEROU!
# gatos00003.png GEROU!
# gatos00004.png GEROU!
# gatos00005.png GEROU!
# gatos00006.png GEROU!
# gatos00007.png GEROU!
# gatos00008.png GEROU!
# gatos00009.png GEROU!
# gatos00010.png GEROU!
# gatos00011.png GEROU!
# gatos00012.png GEROU!
# gatos00013.png GEROU!
# gatos00014.png GEROU!
# gatos00015.png GEROU!
# gatos00016.png GEROU!
# gatos00017.png GEROU!
# gatos00018.png GEROU!
# gatos00019.png GEROU!
# gatos00020.png GEROU!
# gatos00021.png GEROU!
# gatos00022.png GEROU!
# gatos00023.png GEROU!
# gatos00024.png GEROU!
# gatos00025.png GEROU!
# gatos00026.png GEROU!
# gatos00027.png GEROU!
# gatos00028.png GEROU!
# gatos00029.png GEROU!
# gatos00030.png GEROU!
# gatos00031.png GEROU!
# gatos00032.png GEROU!
# gatos00033.png GEROU!
# gatos00034.png GEROU!
# gatos00035.png GEROU!
# gatos00036.png GEROU!
# gatos00037.png GEROU!
# gatos00038.png GEROU!
# gatos00039.png GEROU!
# gatos00040.png GEROU!
# gatos00041.png GEROU!
# gatos00042.png GEROU!
# gatos00043.png GEROU!
# gatos00044.png GEROU!
# gatos00045.png GEROU!
# gatos00046.png GEROU!
# gatos00047.png GEROU!
# gatos00048.png GEROU!
# gatos00049.png GEROU!
# gatos00050.png GEROU!
# gatos00051.png GEROU!
# gatos00052.png GEROU!
# gatos00053.png GEROU!
# gatos00054.png GEROU!
# gatos00055.png GEROU!
# gatos00056.png GEROU!
# gatos00057.png GEROU!
# gatos00058.png GEROU!
# gatos00059.png GEROU!
# gatos00060.png GEROU!
# gatos00061.png GEROU!
# gatos00062.png GEROU!
# gatos00063.png GEROU!
# gatos00064.png GEROU!
# gatos00065.png GEROU!
# gatos00066.png GEROU!
# gatos00067.png GEROU!
# gatos00068.png GEROU!
# gatos00069.png GEROU!
# gatos00070.png GEROU!
# gatos00071.png GEROU!
# gatos00072.png GEROU!
# gatos00073.png GEROU!
# gatos00074.png GEROU!
# gatos00075.png GEROU!
# gatos00076.png GEROU!
# gatos00077.png GEROU!
# gatos00078.png GEROU!
# gatos00079.png GEROU!
# gatos00080.png GEROU!
# gatos00081.png GEROU!
# gatos00082.png GEROU!
# gatos00083.png GEROU!
# gatos00084.png GEROU!
# gatos00085.png GEROU!
# gatos00086.png GEROU!
# gatos00087.png GEROU!
# gatos00088.png GEROU!
# gatos00089.png GEROU!
# gatos00090.png GEROU!
# gatos00091.png GEROU!
# gatos00092.png GEROU!
# gatos00093.png GEROU!
# gatos00094.png GEROU!
# gatos00095.png GEROU!
# gatos00096.png GEROU!
# gatos00097.png GEROU!
# gatos00218.png GEROU!
# gatos00219.png GEROU!
# gatos00220.png GEROU!
# gatos00221.png GEROU!
# gatos00222.png GEROU!
# gatos00223.png GEROU!
# gatos00224.png GEROU!
# gatos00225.png GEROU!
# gatos00226.png GEROU!
# gatos00227.png GEROU!
# gatos00228.png GEROU!
# gatos00229.png GEROU!
# gatos00230.png GEROU!
# gatos00231.png GEROU!
# gatos00232.png GEROU!
# gatos00233.png GEROU!
# gatos00234.png GEROU!

# %%
converter('cv2.TM_CCORR', 'TM_CCORR')
# Out:
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCORR Já Existe!
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCORR/res Já Existe!
# Pasta: /content/drive/MyDrive/PIM/TAREFA FINAL/gatos/TM_CCORR/img Já Existe!
# gatos00001.png GEROU!
# gatos00002.png GEROU!
# gatos00003.png GEROU!
# gatos00004.png GEROU!
# gatos00005.png GEROU!
# gatos00006.png GEROU!
# gatos00007.png GEROU!
# gatos00008.png GEROU!
# gatos00009.png GEROU!
# gatos00010.png GEROU!
# gatos00011.png GEROU!
# gatos00012.png GEROU!
# gatos00013.png GEROU!
# gatos00014.png GEROU!
# gatos00015.png GEROU!
# gatos00016.png GEROU!
# gatos00017.png GEROU!
# gatos00018.png GEROU!
# gatos00019.png GEROU!
# gatos00020.png GEROU!
# gatos00021.png GEROU!
# gatos00022.png GEROU!
# gatos00023.png GEROU!
# gatos00024.png GEROU!
# gatos00025.png GEROU!
# gatos00026.png GEROU!
# gatos00027.png GEROU!
# gatos00028.png GEROU!
# gatos00029.png GEROU!
# gatos00030.png GEROU!
# gatos00031.png GEROU!
# gatos00032.png GEROU!
# gatos00033.png GEROU!
# gatos00034.png GEROU!
# gatos00035.png GEROU!
# gatos00036.png GEROU!
# gatos00037.png GEROU!
# gatos00038.png GEROU!
# gatos00039.png GEROU!
# gatos00040.png GEROU!
# gatos00041.png GEROU!
# gatos00042.png GEROU!
# gatos00043.png GEROU!
# gatos00044.png GEROU!
# gatos00045.png GEROU!
# gatos00046.png GEROU!
# gatos00047.png GEROU!
# gatos00048.png GEROU!
# gatos00049.png GEROU!
# gatos00050.png GEROU!
# gatos00051.png GEROU!
# gatos00052.png GEROU!
# gatos00053.png GEROU!
# gatos00054.png GEROU!
# gatos00055.png GEROU!
# gatos00056.png GEROU!
# gatos00057.png GEROU!
# gatos00058.png GEROU!
# gatos00059.png GEROU!
# gatos00060.png GEROU!
# gatos00061.png GEROU!
# gatos00062.png GEROU!
# gatos00063.png GEROU!
# gatos00064.png GEROU!
# gatos00065.png GEROU!
# gatos00066.png GEROU!
# gatos00067.png GEROU!
# gatos00068.png GEROU!
# gatos00069.png GEROU!
# gatos00070.png GEROU!
# gatos00071.png GEROU!
# gatos00072.png GEROU!
# gatos00073.png GEROU!
# gatos00074.png GEROU!
# gatos00075.png GEROU!
# gatos00076.png GEROU!
# gatos00077.png GEROU!
# gatos00078.png GEROU!
# gatos00079.png GEROU!
# gatos00080.png GEROU!
# gatos00081.png GEROU!
# gatos00082.png GEROU!
# gatos00083.png GEROU!
# gatos00084.png GEROU!
# gatos00085.png GEROU!
# gatos00086.png GEROU!
# gatos00087.png GEROU!
# gatos00088.png GEROU!

# %%
converter('cv2.TM_CCORR_NORMED', 'TM_CCORR_NORMED')

# %%
converter('cv2.TM_SQDIFF', 'TM_SQDIFF')

# %%
converter('cv2.TM_SQDIFF_NORMED', 'TM_SQDIFF_NORMED')
